# %%
from web3 import Web3

# 使用Alchemy或Infura的API连接到Base链
w3 = Web3(Web3.HTTPProvider('https://base-alchemy-url'))

# 获取交易数据
transaction = w3.eth.getTransaction('交易哈希')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 7
#       4 w3 = Web3(Web3.HTTPProvider('https://base-alchemy-url'))
#       6 # 获取交易数据
# ----> 7 transaction = w3.eth.getTransaction('交易哈希')
#
# AttributeError: 'Eth' object has no attribute 'getTransaction'

# %%
w3
